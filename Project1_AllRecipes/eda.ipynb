# %% [markdown]
# # Project 1 - Normalizing AllRecipes Data
#
# Welcome to our first project! In this challenge, we will be tackling the normalization and
# analysis of the ["All Recipes 14K Recipes with Nutrition"](https://www.kaggle.com/datasets/ibrahimqasimi/allrecipes-14k-recipes-with-nutrition)
# dataset from Kaggle user Mihammad Ibrahim Qasmi.
#
# This dataset has been downloaded from Kaggle as a CSV file and placed in the [data folder](./data) in this project.
#
#
# ## Exploratory Data Analysis
#
# Exploratory data analysis is the process of understanding the data available to you and is composed of automatic and manual analysis methods.
#
# Automatic methods include looking at the distributions and key statistics for numerical columns while manual methods involve viewing samples of columns. This is not an all-encompassing explanation, just a short introduction.
#
# Below I'll walk you through the introduction to EDA that we'll be using for this project. Please feel free to add onto it, just mark your additions with comments in both the Markdown and the code!

# %% [markdown]
# ### Step 1. Imports
#
# Below I've imported the most common packages that we'll need in Python for EDA. Feel free to bring in more as needed!

# %%
# Standard Library
from pathlib import Path
import os

# Pip Packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


# Pandas Settings for best viewing in Jupyter
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Next we'll import the data itself into a `pandas` DataFrame!

# %%
data_path = Path("./data/allrecipes_14k.csv")

if data_path.exists():
    with open(data_path, "r", encoding="utf-8") as dfile:
        recipes_orig = pd.read_csv(dfile)

# %%
# Examine new DataFrame
recipes_orig.head()
# Out:
#                                        name  \
# 0  Chewy Whole Wheat Peanut Butter Brownies
# 1                        Pumpkin Pie Eggnog
# 2              Eggs Poached in Tomato Sauce
# 3                      Minestrone Casserole
# 4                     Yummy Stuffed Peppers
#
#                                                  url         author  \
# 0  https://www.allrecipes.com/recipe/140717/chewy...         DMOMMY
# 1  https://www.allrecipes.com/recipe/269204/pumpk...   Bobbie Susan
# 2  https://www.allrecipes.com/recipe/238054/eggs-...           Bren
# 3  https://www.allrecipes.com/minestrone-casserol...   Sarah Brekke
# 4  https://www.allrecipes.com/recipe/241937/yummy...  Procrastigirl
#
#   date_published                                        ingredients  calories  \
# 0     2020-06-18  ⅓ cup margarine, softened, ⅔ cup white sugar, ...     222.0
# 1     2022-09-26  12  egg yolks, 2 cups heavy whipping cream, ½ ...     477.0
# ...
